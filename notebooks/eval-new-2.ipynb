# %% [markdown]
# ## Generate Result Tables
# - MCHAD
# - CAC
# - II
# - Center Loss
# - G-MCHAD
# - G-Center
# - G-CAC

# %%
import seaborn as sb
import matplotlib.pyplot as plt
from omegaconf import OmegaConf
import pandas as pd
from os.path import join

# %%
sb.set()
sb.set_style("whitegrid")
sb.set_context("paper")

# %%
# root folder for experiment run
root = "/home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/"

# %%
# map test cases
dataset_map = {
    "test_vs_uniformnoise": "Uniform",
    "test_vs_gaussiannoise": "Gaussian",
    "test_vs_tinycrop": "Tiny Crop",
    "test_vs_tinyresize": "Tiny Resize",
    "test_vs_lsuncrop": "LSUN Crop",
    "test_vs_lsunresize": "LSUN Resize",
    "test_vs_textures": "Texture",
}

model_map = {
    "src.models.CAC": "CAC",
    "src.models.Softmax": "Softmax",
    "src.models.MCHAD": "MCHAD",
    "src.models.Center": "Center",
    "src.models.II": "II",
    "src.models.GCAC": "G-CAC",
    "src.models.GCenter": "G-Center",
}


train_dataset_map = {
    "src.datamodules.CIFAR10DataModule": "CIFAR10",
    "src.datamodules.SVHNDataModule": "SVHN",
    "src.datamodules.CIFAR100DataModule": "CIFAR100",
}

# %%
def convert(df, key="Distance", task="OOD"):
    """
    Get correct metrics from dataframe
    """
    df.rename(
        inplace=True,
        columns={
            "Accuracy/test": "Accuracy",
            f"{key}/{task}/AUROC/test": "AUROC",
            f"{key}/{task}/AUPR-IN/test": "AUPR-IN",
            f"{key}/{task}/AUPR-OUT/test": "AUPR-OUT",
            f"{key}/{task}/FPR95TPR/test": "FPR95",
        },
    )

    return df

# %%
directories = []
# directories += [f"./svhn/center/{i}" for i in range(21)]
# directories += [f"./svhn/mchad/{i}" for i in range(21)]
directories += [f"./svhn/gmchad/{i}" for i in range(21)]
directories += [f"./svhn/gcenter/{i}" for i in range(21)]
directories += [f"./svhn/gcac/{i}" for i in range(21)]
# directories += [f"./svhn/cac/{i}" for i in range(21)]
# directories += [f"./svhn/ii/{i}" for i in range(21)]

# directories += [f"./cifar100/mchad/{i}" for i in range(21)]
directories += [f"./cifar100/gmchad/{i}" for i in range(21)]
directories += [f"./cifar100/gcenter/{i}" for i in range(21)]
directories += [f"./cifar100/gcac/{i}" for i in range(21)]
# directories += [f"./cifar100/cac/{i}" for i in range(21)]
# directories += [f"./cifar100/ii/{i}" for i in range(21)]
# directories += [f"./cifar100/center/{i}" for i in range(21)]


# del directories[directories.index("./cifar100/cac/13")]
# directories += [f"./cifar10/mchad/{i}" for i in range(21)]
# directories += [f"./cifar10/center/{i}" for i in range(21)]
directories += [f"./cifar10/gmchad/{i}" for i in range(21)]
directories += [f"./cifar10/gcenter/{i}" for i in range(21)]
directories += [f"./cifar10/gcac/{i}" for i in range(21)]
# directories += [f"./cifar10/cac/{i}" for i in range(21)]
# directories += [f"./cifar10/ii/{i}" for i in range(21)]

# %%
def get_training_set(datamodule):
    target = datamodule["_target_"]
    d = train_dataset_map.get(target)

    if not d:
        if target == "src.datamodules.MultiDatamodule":
            d = train_dataset_map.get(datamodule["module1"]["_target_"])

    if not d:
        print(datamodule)
    else:
        print(d)

    return d


def load(path):
    local_df = []

    df = pd.read_csv(join(path, "results.csv"))
    metrics = pd.read_csv(join(path, "csv/version_0/metrics.csv"))
    config = OmegaConf.load(join(path, "tb/version_0/hparams.yaml"))
    df["Dataset"] = get_training_set(config["datamodule"])
    df["Outliers"] = df["test_case_name"].apply(dataset_map.get)
    model = str(config["model"]["_target_"])

    if model == "src.models.CAC":
        df["Model"] = "CAC"
        df = convert(df, "Distance")
    elif model == "src.models.SoftMax":
        print("EB-OOD")
        df_ebm = df.copy(deep=True)
        df_ebm["Model"] = "EB-OOD"
        df_emb = convert(df_ebm, "EnergyBased")

        local_df.append(df_ebm)

        print("Softmax")
        df["Model"] = "Softmax"
        df = convert(df, "Softmax")

    elif model == "src.models.MCHAD":
        if config["model"]["weight_oe"] == 0.0:
            # print(f"Weight OE: {config['model']['weight_oe']}")
            df["Model"] = "MCHAD"
        else:
            print(f"Weight OE: {config['model']['weight_oe']}")
            df["Model"] = "G-MCHAD"

        df = convert(df)
    elif model == "src.models.Center":
        df["Model"] = "Center"
        df = convert(df, "Distance")
    elif model == "src.models.IIModel":
        df["Model"] = "II"
        df = convert(df)
    elif model == "src.models.GCenter":
        df["Model"] = "G-Center"
        df = convert(df, key="Distance")
    elif model == "src.models.GCAC":
        df["Model"] = "G-CAC"
        df = convert(df, key="Distance")
    else:
        raise Exception(f"UNKNOWN: {model}")

    local_df.append(df)
    return config, pd.concat(local_df), metrics

# %%
dfs = []

for d in directories:
    # filter(lambda x: "center" not in x and "cifar100/softmax/" not in x and "mchad-o" not in x, directories):
    path = join(root, d)
    config, df, metrics = load(path)
    try:
        if df is not None:
            print(path)
            print(
                f"{df['Dataset'][0]}/{df['Model'][0]} -> {df['AUROC'].mean()} {len(df)}"
            )
            df = df[
                [
                    "Accuracy",
                    "AUROC",
                    "AUPR-IN",
                    "AUPR-OUT",
                    "FPR95",
                    "Dataset",
                    "Outliers",
                    "Model",
                ]
            ]
            dfs.append(df.copy())
    except Exception as e:
        print("EXCEPTION WHILE LOADING")
        print(type(e), e)
        print(df.columns)

df = pd.concat(dfs)
# Out:
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/0
# SVHN/G-MCHAD -> 0.8706583976745605 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/1
# SVHN/G-MCHAD -> 0.8689311891794205 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/2
# SVHN/G-MCHAD -> 0.867965966463089 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/3
# SVHN/G-MCHAD -> 0.8681197017431259 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/4
# SVHN/G-MCHAD -> 0.8707436546683311 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/5
# SVHN/G-MCHAD -> 0.8702791258692741 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/6
# SVHN/G-MCHAD -> 0.8706935569643974 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/7
# SVHN/G-MCHAD -> 0.8645285591483116 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/8
# SVHN/G-MCHAD -> 0.8695268481969833 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/9
# SVHN/G-MCHAD -> 0.8715179264545441 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/10
# SVHN/G-MCHAD -> 0.8694092407822609 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/11
# SVHN/G-MCHAD -> 0.8710493445396423 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/12
# SVHN/G-MCHAD -> 0.8620708659291267 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/13
# SVHN/G-MCHAD -> 0.8695423901081085 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/14
# SVHN/G-MCHAD -> 0.8683955743908882 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/15
# SVHN/G-MCHAD -> 0.871121309697628 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/16
# SVHN/G-MCHAD -> 0.8708923906087875 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/17
# SVHN/G-MCHAD -> 0.8717109709978104 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/18
# SVHN/G-MCHAD -> 0.868150606751442 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/19
# SVHN/G-MCHAD -> 0.8710226193070412 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gmchad/20
# SVHN/G-MCHAD -> 0.865582637488842 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/0
# SVHN/G-Center -> 0.8719315379858017 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/1
# SVHN/G-Center -> 0.8675276562571526 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/2
# SVHN/G-Center -> 0.8705172836780548 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/3
# SVHN/G-Center -> 0.8680973052978516 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/4
# SVHN/G-Center -> 0.8711211681365967 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/5
# SVHN/G-Center -> 0.8707365468144417 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/6
# SVHN/G-Center -> 0.8670480325818062 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/7
# SVHN/G-Center -> 0.8709159791469574 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/8
# SVHN/G-Center -> 0.8662321269512177 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/9
# SVHN/G-Center -> 0.8713389709591866 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/10
# SVHN/G-Center -> 0.8712283372879028 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/11
# SVHN/G-Center -> 0.8701379895210266 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/12
# SVHN/G-Center -> 0.8706371262669563 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/13
# SVHN/G-Center -> 0.8669313043355942 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/14
# SVHN/G-Center -> 0.8694569990038872 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/15
# SVHN/G-Center -> 0.8730748742818832 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/16
# SVHN/G-Center -> 0.8674564585089684 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/17
# SVHN/G-Center -> 0.8709268718957901 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/18
# SVHN/G-Center -> 0.8708432167768478 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/19
# SVHN/G-Center -> 0.8676318749785423 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcenter/20
# SVHN/G-Center -> 0.8657667562365532 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/0
# SVHN/G-CAC -> 0.8640386387705803 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/1
# SVHN/G-CAC -> 0.8715785443782806 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/2
# SVHN/G-CAC -> 0.8700590431690216 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/3
# SVHN/G-CAC -> 0.8653675839304924 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/4
# SVHN/G-CAC -> 0.8681000620126724 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/5
# SVHN/G-CAC -> 0.8603026121854782 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/6
# SVHN/G-CAC -> 0.8703809082508087 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/7
# SVHN/G-CAC -> 0.8704506009817123 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/8
# SVHN/G-CAC -> 0.8682860732078552 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/9
# SVHN/G-CAC -> 0.8664968609809875 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/10
# SVHN/G-CAC -> 0.8708399161696434 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/11
# SVHN/G-CAC -> 0.8714946880936623 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/12
# SVHN/G-CAC -> 0.8703149631619453 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/13
# SVHN/G-CAC -> 0.8678921461105347 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/14
# SVHN/G-CAC -> 0.8707689344882965 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/15
# SVHN/G-CAC -> 0.8597770482301712 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/16
# SVHN/G-CAC -> 0.8645678162574768 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/17
# SVHN/G-CAC -> 0.8689442276954651 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/18
# SVHN/G-CAC -> 0.869424007833004 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/19
# SVHN/G-CAC -> 0.8659784868359566 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./svhn/gcac/20
# SVHN/G-CAC -> 0.8677640780806541 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/0
# CIFAR100/G-MCHAD -> 0.5606767870485783 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/1
# CIFAR100/G-MCHAD -> 0.610850602388382 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/2
# CIFAR100/G-MCHAD -> 0.724940113723278 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/3
# CIFAR100/G-MCHAD -> 0.6929700598120689 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/4
# CIFAR100/G-MCHAD -> 0.7266858518123627 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/5
# CIFAR100/G-MCHAD -> 0.7597557753324509 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/6
# CIFAR100/G-MCHAD -> 0.6311317384243011 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/7
# CIFAR100/G-MCHAD -> 0.6451953798532486 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/8
# CIFAR100/G-MCHAD -> 0.7421750500798225 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/9
# CIFAR100/G-MCHAD -> 0.7328279316425323 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/10
# CIFAR100/G-MCHAD -> 0.6470140367746353 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/11
# CIFAR100/G-MCHAD -> 0.5517865549772978 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/12
# CIFAR100/G-MCHAD -> 0.7371219843626022 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/13
# CIFAR100/G-MCHAD -> 0.6944529190659523 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/14
# CIFAR100/G-MCHAD -> 0.6185047812759876 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/15
# CIFAR100/G-MCHAD -> 0.6174813657999039 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/16
# CIFAR100/G-MCHAD -> 0.5953960455954075 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/17
# CIFAR100/G-MCHAD -> 0.6723718717694283 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/18
# CIFAR100/G-MCHAD -> 0.6737183183431625 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/19
# CIFAR100/G-MCHAD -> 0.5958144329488277 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gmchad/20
# CIFAR100/G-MCHAD -> 0.7559407353401184 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/0
# CIFAR100/G-Center -> 0.4964929483830929 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/1
# CIFAR100/G-Center -> 0.5087269060313702 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/2
# CIFAR100/G-Center -> 0.413407064974308 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/3
# CIFAR100/G-Center -> 0.48933572974056005 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/4
# CIFAR100/G-Center -> 0.4034273764118552 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/5
# CIFAR100/G-Center -> 0.5108222691342235 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/6
# CIFAR100/G-Center -> 0.41235120315104723 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/7
# CIFAR100/G-Center -> 0.5114536951296031 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/8
# CIFAR100/G-Center -> 0.3313668076880276 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/9
# CIFAR100/G-Center -> 0.5286174565553665 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/10
# CIFAR100/G-Center -> 0.2997466176748276 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/11
# CIFAR100/G-Center -> 0.44651118014007807 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/12
# CIFAR100/G-Center -> 0.5423380583524704 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/13
# CIFAR100/G-Center -> 0.3242133753374219 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/14
# CIFAR100/G-Center -> 0.34112356789410114 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/15
# CIFAR100/G-Center -> 0.3486342914402485 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/16
# CIFAR100/G-Center -> 0.4915891708806157 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/17
# CIFAR100/G-Center -> 0.4360937518067658 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/18
# CIFAR100/G-Center -> 0.5044230008497834 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/19
# CIFAR100/G-Center -> 0.4330539032816887 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcenter/20
# CIFAR100/G-Center -> 0.5460135759785771 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/0
# CIFAR100/G-CAC -> 0.27894541807472706 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/1
# CIFAR100/G-CAC -> 0.41614696756005287 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/2
# CIFAR100/G-CAC -> 0.6901605650782585 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/3
# CIFAR100/G-CAC -> 0.642790075391531 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/4
# CIFAR100/G-CAC -> 0.33237938582897186 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/5
# CIFAR100/G-CAC -> 0.5174901150166988 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/6
# CIFAR100/G-CAC -> 0.4514824419748038 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/7
# CIFAR100/G-CAC -> 0.16308842797297984 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/8
# CIFAR100/G-CAC -> 0.42710432073818083 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/9
# CIFAR100/G-CAC -> 0.32219118624925613 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/10
# CIFAR100/G-CAC -> 0.5686005838215351 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/11
# CIFAR100/G-CAC -> 0.47681184113025665 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/12
# CIFAR100/G-CAC -> 0.66409070789814 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/13
# CIFAR100/G-CAC -> 0.5560344830155373 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/14
# CIFAR100/G-CAC -> 0.19968540966510767 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/15
# CIFAR100/G-CAC -> 0.4056469202041626 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/16
# CIFAR100/G-CAC -> 0.483502957271412 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/17
# CIFAR100/G-CAC -> 0.288207957171835 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/18
# CIFAR100/G-CAC -> 0.5034820353612304 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/19
# CIFAR100/G-CAC -> 0.6948109269142151 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar100/gcac/20
# CIFAR100/G-CAC -> 0.2504821388865821 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/0
# CIFAR10/G-MCHAD -> 0.851168155670166 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/1
# CIFAR10/G-MCHAD -> 0.8557462841272354 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/2
# CIFAR10/G-MCHAD -> 0.8358225524425507 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/3
# CIFAR10/G-MCHAD -> 0.8569643497467041 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/4
# CIFAR10/G-MCHAD -> 0.848333440721035 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/5
# CIFAR10/G-MCHAD -> 0.8325530588626862 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/6
# CIFAR10/G-MCHAD -> 0.851886123418808 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/7
# CIFAR10/G-MCHAD -> 0.8047901391983032 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/8
# CIFAR10/G-MCHAD -> 0.8456901088356972 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/9
# CIFAR10/G-MCHAD -> 0.8519541844725609 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/10
# CIFAR10/G-MCHAD -> 0.8534782752394676 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/11
# CIFAR10/G-MCHAD -> 0.8447244837880135 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/12
# CIFAR10/G-MCHAD -> 0.8349450007081032 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/13
# CIFAR10/G-MCHAD -> 0.8524571284651756 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/14
# CIFAR10/G-MCHAD -> 0.8574600517749786 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/15
# CIFAR10/G-MCHAD -> 0.8563319817185402 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/16
# CIFAR10/G-MCHAD -> 0.8475485891103745 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/17
# CIFAR10/G-MCHAD -> 0.8341162651777267 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/18
# CIFAR10/G-MCHAD -> 0.8570855110883713 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/19
# CIFAR10/G-MCHAD -> 0.8446696773171425 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gmchad/20
# CIFAR10/G-MCHAD -> 0.8497775718569756 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/0
# CIFAR10/G-Center -> 0.8260157406330109 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/1
# CIFAR10/G-Center -> 0.8219315931200981 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/2
# CIFAR10/G-Center -> 0.8193091377615929 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/3
# CIFAR10/G-Center -> 0.819840170443058 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/4
# CIFAR10/G-Center -> 0.8264211118221283 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/5
# CIFAR10/G-Center -> 0.8151126578450203 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/6
# CIFAR10/G-Center -> 0.7993651404976845 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/7
# CIFAR10/G-Center -> 0.8021809384226799 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/8
# CIFAR10/G-Center -> 0.8238414227962494 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/9
# CIFAR10/G-Center -> 0.8216995671391487 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/10
# CIFAR10/G-Center -> 0.7665381133556366 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/11
# CIFAR10/G-Center -> 0.7770422548055649 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/12
# CIFAR10/G-Center -> 0.8029297366738319 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/13
# CIFAR10/G-Center -> 0.8207850828766823 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/14
# CIFAR10/G-Center -> 0.8261912539601326 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/15
# CIFAR10/G-Center -> 0.8193211480975151 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/16
# CIFAR10/G-Center -> 0.8246635496616364 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/17
# CIFAR10/G-Center -> 0.8148290738463402 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/18
# CIFAR10/G-Center -> 0.7933616787195206 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/19
# CIFAR10/G-Center -> 0.822983555495739 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcenter/20
# CIFAR10/G-Center -> 0.7958658635616302 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/0
# CIFAR10/G-CAC -> 0.8233027160167694 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/1
# CIFAR10/G-CAC -> 0.808640293776989 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/2
# CIFAR10/G-CAC -> 0.34381389804184437 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/3
# CIFAR10/G-CAC -> 0.8253752961754799 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/4
# CIFAR10/G-CAC -> 0.8085657954216003 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/5
# CIFAR10/G-CAC -> 0.5139525458216667 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/6
# CIFAR10/G-CAC -> 0.8204543218016624 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/7
# CIFAR10/G-CAC -> 0.802909791469574 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/8
# CIFAR10/G-CAC -> 0.4778631515800953 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/9
# CIFAR10/G-CAC -> 0.3944430947303772 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/10
# CIFAR10/G-CAC -> 0.8189882412552834 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/11
# CIFAR10/G-CAC -> 0.817067414522171 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/12
# CIFAR10/G-CAC -> 0.8359983414411545 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/13
# CIFAR10/G-CAC -> 0.8271771818399429 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/14
# CIFAR10/G-CAC -> 0.834849551320076 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/15
# CIFAR10/G-CAC -> 0.7926690354943275 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/16
# CIFAR10/G-CAC -> 0.8327417299151421 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/17
# CIFAR10/G-CAC -> 0.8340009823441505 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/18
# CIFAR10/G-CAC -> 0.8316622823476791 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/19
# CIFAR10/G-CAC -> 0.6136246211826801 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-20:12:40/./cifar10/gcac/20
# CIFAR10/G-CAC -> 0.8292619585990906 8

# %%
df["AUROC"] = df["AUROC"].apply(lambda x: x * 100)
df["AUPR-IN"] = df["AUPR-IN"].apply(lambda x: x * 100)
df["AUPR-OUT"] = df["AUPR-OUT"].apply(lambda x: x * 100)
df["FPR95"] = df["FPR95"].apply(lambda x: x * 100)
df["Accuracy"] = df["Accuracy"].apply(lambda x: x * 100)

# %%
# , "Tiny Crop", "LSUN Crop"
# df = df[df["Outliers"].isin(["Texture", "Tiny Resize", "LSUN Resize", "Uniform", "Gaussian"])]
df = df.set_index(["Dataset", "Outliers", "Model"]).dropna()

# %%
from itertools import product
datasets = ["SVHN", "CIFAR10", "CIFAR100"]
# models = ["CAC", "II", "Center", "Softmax", "EB-OOD", "MCHAD", "G-MCHAD"]
models = ["MCHAD", "II", "CAC", "Center", "G-MCHAD", "G-Center", "G-CAC"]

t =  df.reset_index().groupby(by=["Dataset", "Model"]).agg(
        {
            "Accuracy": ["mean", "sem"],
            "AUROC": ["mean", "sem"],
            "AUPR-IN": ["mean", "sem"],
            "AUPR-OUT": ["mean", "sem"],
            "FPR95": ["mean", "sem"],
        }
    ).reindex(list(product(datasets, models)))

s = t.to_latex(
        float_format="%.2f",
        multirow=True,
        escape=False,
        label="tab:results",
        # bold_rows="True",
    )

repl = {
    "mean": "Mean",
    "sem": "$\\pm \sigma_{\\bar{x}}$",
    " MCHAD": " \\textbf{MCHAD (ours)}",
    "G-MCHAD": "\\textbf{G-MCHAD (ours)}",
    "G-Center": "\\textbf{G-Center (ours)}",
    "G-CAC": "\\textbf{G-CAC (ours)}",
}

for k, v in repl.items():
    s = s.replace(k, v)

print(s)
# Out:
# \begin{table}
# \centering
# \label{tab:results}
# \begin{tabular}{llrrrrrrrrrr}
# \toprule
#          &       & \multicolumn{2}{l}{Accuracy} & \multicolumn{2}{l}{AUROC} & \multicolumn{2}{l}{AUPR-IN} & \multicolumn{2}{l}{AUPR-OUT} & \multicolumn{2}{l}{FPR95} \\
#          &       &     Mean &  $\pm \sigma_{\bar{x}}$ &  Mean &  $\pm \sigma_{\bar{x}}$ &    Mean &  $\pm \sigma_{\bar{x}}$ &     Mean &  $\pm \sigma_{\bar{x}}$ &  Mean &  $\pm \sigma_{\bar{x}}$ \\
# Dataset & Model &          &      &       &      &         &      &          &      &       &      \\
# \midrule
# \multirow{7}{*}{SVHN} & \textbf{MCHAD (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & II &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & CAC &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & Center &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-MCHAD (ours)} &    95.67 & 0.01 & 99.33 & 0.06 &   96.92 & 0.29 &    99.78 & 0.02 &  2.22 & 0.19 \\
#          & \textbf{G-Center (ours)} &    95.87 & 0.01 & 99.37 & 0.10 &   98.40 & 0.25 &    99.72 & 0.05 &  2.45 & 0.37 \\
#          & \textbf{G-CAC (ours)} &    94.16 & 0.02 & 99.17 & 0.13 &   97.88 & 0.37 &    99.48 & 0.09 &  2.82 & 0.51 \\
# \cline{1-12}
# \multirow{7}{*}{CIFAR10} & \textbf{MCHAD (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & II &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & CAC &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & Center &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-MCHAD (ours)} &    94.72 & 0.01 & 96.69 & 0.21 &   94.40 & 0.42 &    97.56 & 0.15 & 10.37 & 0.57 \\
#          & \textbf{G-Center (ours)} &    94.24 & 0.01 & 92.74 & 0.55 &   88.50 & 0.89 &    94.35 & 0.43 & 20.43 & 1.28 \\
#          & \textbf{G-CAC (ours)} &    84.51 & 1.71 & 84.28 & 1.63 &   82.83 & 1.63 &    84.43 & 1.42 & 41.75 & 2.92 \\
# \cline{1-12}
# \multirow{7}{*}{CIFAR100} & \textbf{MCHAD (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & II &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & CAC &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & Center &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-MCHAD (ours)} &    75.67 & 0.02 & 76.12 & 1.39 &   71.56 & 1.41 &    81.02 & 1.06 & 53.37 & 2.27 \\
#          & \textbf{G-Center (ours)} &    70.84 & 0.05 & 50.72 & 2.63 &   53.56 & 1.62 &    61.79 & 1.92 & 75.03 & 2.33 \\
#          & \textbf{G-CAC (ours)} &     1.58 & 0.03 & 50.79 & 2.52 &   57.43 & 1.93 &    57.72 & 1.88 & 79.53 & 2.84 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
methods = ["MCHAD", "II", "CAC", "Center", "G-MCHAD", "G-Center", "G-CAC"]
# ,
for dataset in ["CIFAR10", "SVHN", "CIFAR100"]:
    g = sb.catplot(
        data=df.reset_index()[df.reset_index()["Dataset"] == dataset],
        x="Outliers",
        y="AUROC",
        kind="bar",
        hue="Model",
        col="Dataset",
        hue_order=methods
    )
    g.set_xticklabels(rotation=30)
    plt.savefig(f"out/single-auroc-{dataset}.png", dpi=300)
    plt.show()

# %%
tmp = df.reset_index().copy()
# tmp = tmp[(tmp["Model"] == "MCHAD") | (tmp["Model"] == "G-MCHAD")| (tmp["Model"] == "G-CAC") | (tmp["Model"] == "G-Center")]

print(
    tmp
    .groupby(by=["Dataset", "Model"])
    .agg(
        {
            "Accuracy": ["mean", "sem"],
            "AUROC": ["mean", "sem"],
            "AUPR-IN": ["mean", "sem"],
            "AUPR-OUT": ["mean", "sem"],
            "FPR95": ["mean", "sem"],
        }
    )
    .to_html(
        float_format="%.2f",
        escape=False,
    )
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">Accuracy</th>
#       <th colspan="2" halign="left">AUROC</th>
#       <th colspan="2" halign="left">AUPR-IN</th>
#       <th colspan="2" halign="left">AUPR-OUT</th>
#       <th colspan="2" halign="left">FPR95</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#     </tr>
#     <tr>
#       <th>Dataset</th>
#       <th>Model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">CIFAR10</th>
#       <th>G-CAC</th>
#       <td>84.51</td>
#       <td>1.71</td>
#       <td>84.28</td>
#       <td>1.63</td>
#       <td>82.83</td>
#       <td>1.63</td>
#       <td>84.43</td>
#       <td>1.42</td>
#       <td>41.75</td>
#       <td>2.92</td>
#     </tr>
#     <tr>
#       <th>G-Center</th>
#       <td>94.24</td>
#       <td>0.01</td>
#       <td>92.74</td>
#       <td>0.55</td>
#       <td>88.50</td>
#       <td>0.89</td>
#       <td>94.35</td>
#       <td>0.43</td>
#       <td>20.43</td>
#       <td>1.28</td>
#     </tr>
#     <tr>
#       <th>G-MCHAD</th>
#       <td>94.72</td>
#       <td>0.01</td>
#       <td>96.69</td>
#       <td>0.21</td>
#       <td>94.40</td>
#       <td>0.42</td>
#       <td>97.56</td>
#       <td>0.15</td>
#       <td>10.37</td>
#       <td>0.57</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">CIFAR100</th>
#       <th>G-CAC</th>
#       <td>1.58</td>
#       <td>0.03</td>
#       <td>50.79</td>
#       <td>2.52</td>
#       <td>57.43</td>
#       <td>1.93</td>
#       <td>57.72</td>
#       <td>1.88</td>
#       <td>79.53</td>
#       <td>2.84</td>
#     </tr>
#     <tr>
#       <th>G-Center</th>
#       <td>70.84</td>
#       <td>0.05</td>
#       <td>50.72</td>
#       <td>2.63</td>
#       <td>53.56</td>
#       <td>1.62</td>
#       <td>61.79</td>
#       <td>1.92</td>
#       <td>75.03</td>
#       <td>2.33</td>
#     </tr>
#     <tr>
#       <th>G-MCHAD</th>
#       <td>75.67</td>
#       <td>0.02</td>
#       <td>76.12</td>
#       <td>1.39</td>
#       <td>71.56</td>
#       <td>1.41</td>
#       <td>81.02</td>
#       <td>1.06</td>
#       <td>53.37</td>
#       <td>2.27</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">SVHN</th>
#       <th>G-CAC</th>
#       <td>94.16</td>
#       <td>0.02</td>
#       <td>99.17</td>
#       <td>0.13</td>
#       <td>97.88</td>
#       <td>0.37</td>
#       <td>99.48</td>
#       <td>0.09</td>
#       <td>2.82</td>
#       <td>0.51</td>
#     </tr>
#     <tr>
#       <th>G-Center</th>
#       <td>95.87</td>
#       <td>0.01</td>
#       <td>99.37</td>
#       <td>0.10</td>
#       <td>98.40</td>
#       <td>0.25</td>
#       <td>99.72</td>
#       <td>0.05</td>
#       <td>2.45</td>
#       <td>0.37</td>
#     </tr>
#     <tr>
#       <th>G-MCHAD</th>
#       <td>95.67</td>
#       <td>0.01</td>
#       <td>99.33</td>
#       <td>0.06</td>
#       <td>96.92</td>
#       <td>0.29</td>
#       <td>99.78</td>
#       <td>0.02</td>
#       <td>2.22</td>
#       <td>0.19</td>
#     </tr>
#   </tbody>
# </table>

# %%
tmp.groupby(by=["Dataset", "Model"]).agg(
    {
        "Accuracy": ["mean", "sem"],
        "AUROC": ["mean", "sem"],
        "AUPR-IN": ["mean", "sem"],
        "AUPR-OUT": ["mean", "sem"],
        "FPR95": ["mean", "sem"],
    }
)
# Out:
#                     Accuracy                AUROC              AUPR-IN  \
#                         mean       sem       mean       sem       mean
# Dataset  Model
# CIFAR10  G-CAC     84.509524  1.711160  84.284965  1.629972  82.826015
#          G-Center  94.235238  0.011709  92.735939  0.550626  88.504629
#          G-MCHAD   94.718095  0.014786  96.693894  0.214558  94.401462
# CIFAR100 G-CAC      1.580476  0.032026  50.792571  2.515231  57.427524
#          G-Center  70.838571  0.049029  50.719684  2.629890  53.561083
#          G-MCHAD   75.666667  0.018151  76.118707  1.392972  71.555347
# SVHN     G-CAC     94.161033  0.023691  99.171849  0.130823  97.881806
#          G-Center  95.871016  0.012485  99.371746  0.097839  98.396116
#          G-MCHAD   95.671627  0.010118  99.330138  0.058457  96.916652
#
#                               AUPR-OUT                FPR95
#                         sem       mean       sem       mean       sem
# Dataset  Model
# CIFAR10  G-CAC     1.632475  84.429609  1.417579  41.751565  2.920331
#          G-Center  0.894544  94.348413  0.427471  20.432585  1.275459
#          G-MCHAD   0.418196  97.562003  0.151629  10.366531  0.565787
# CIFAR100 G-CAC     1.934548  57.717837  1.880677  79.527687  2.844542
#          G-Center  1.616889  61.792174  1.919616  75.025374  2.330537
#          G-MCHAD   1.405684  81.022114  1.062231  53.369252  2.272481
# SVHN     G-CAC     0.370254  99.479250  0.090211   2.820260  0.507797
#          G-Center  0.253044  99.719478  0.045022   2.448190  0.371209
#          G-MCHAD   0.291789  99.780752  0.019750   2.215092  0.189653

# %%
from scipy.stats import ttest_ind

tmp = df.reset_index().copy()
# tmp = tmp[(tmp["Model"] == "MCHAD") | (tmp["Model"] == "G-MCHAD")]

for metric in ["Accuracy", "AUROC", "AUPR-IN", "AUPR-OUT", "FPR95"]:
    for dataset in ["SVHN", "CIFAR10", "CIFAR100"]:
        a = tmp[(tmp["Model"] == "CAC") & (tmp["Dataset"] == dataset)][metric]
        b = tmp[(tmp["Model"] == "MCHAD") & (tmp["Dataset"]== dataset)][metric]
        stat, p = ttest_ind(a,b, equal_var=False)
        print(f"{metric} {dataset} -> {p < 0.05} ")
# Out:
# Accuracy SVHN -> False
# Accuracy CIFAR10 -> False
# Accuracy CIFAR100 -> False
# AUROC SVHN -> False
# AUROC CIFAR10 -> False
# AUROC CIFAR100 -> False
# AUPR-IN SVHN -> False
# AUPR-IN CIFAR10 -> False
# AUPR-IN CIFAR100 -> False
# AUPR-OUT SVHN -> False
# AUPR-OUT CIFAR10 -> False
# AUPR-OUT CIFAR100 -> False
# FPR95 SVHN -> False
# FPR95 CIFAR10 -> False
# FPR95 CIFAR100 -> False

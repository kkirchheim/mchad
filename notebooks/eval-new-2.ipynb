# %% [markdown]
# ## Generate Result Tables
# - MCHAD
# - CAC
# - II
# - Center Loss
# - G-MCHAD
# - G-Center
# - G-CAC

# %%
import seaborn as sb
import matplotlib.pyplot as plt
from omegaconf import OmegaConf
import pandas as pd
from os.path import join

# %%
sb.set()
sb.set_style("whitegrid")
sb.set_context("paper")

# %%
# root folder for experiment run
root = "/home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/"

# %%
# map test cases
dataset_map = {
    "test_vs_uniformnoise": "Uniform",
    "test_vs_gaussiannoise": "Gaussian",
    "test_vs_tinycrop": "Tiny Crop",
    "test_vs_tinyresize": "Tiny Resize",
    "test_vs_lsuncrop": "LSUN Crop",
    "test_vs_lsunresize": "LSUN Resize",
    "test_vs_textures": "Texture",
}

model_map = {
    "src.models.CAC": "CAC",
    "src.models.Softmax": "Softmax",
    "src.models.MCHAD": "MCHAD",
    "src.models.Center": "Center",
    "src.models.II": "II",
    "src.models.GCAC": "G-CAC",
    "src.models.GCenter": "G-Center",
}


train_dataset_map = {
    "src.datamodules.CIFAR10DataModule": "CIFAR10",
    "src.datamodules.SVHNDataModule": "SVHN",
    "src.datamodules.CIFAR100DataModule": "CIFAR100",
}

# %%
def convert(df, key="Distance", task="OOD"):
    """
    Get correct metrics from dataframe
    """
    df.rename(
        inplace=True,
        columns={
            "Accuracy/test": "Accuracy",
            f"{key}/{task}/AUROC/test": "AUROC",
            f"{key}/{task}/AUPR-IN/test": "AUPR-IN",
            f"{key}/{task}/AUPR-OUT/test": "AUPR-OUT",
            f"{key}/{task}/FPR95TPR/test": "FPR95",
        },
    )

    return df

# %%
directories = []
# # directories += [f"./svhn/center/{i}" for i in range(21)]
# # directories += [f"./svhn/mchad/{i}" for i in range(21)]
# directories += [f"./svhn/gmchad/{i}" for i in range(21)]
# directories += [f"./svhn/gcenter/{i}" for i in range(21)]
# directories += [f"./svhn/gcac/{i}" for i in range(21)]
# # directories += [f"./svhn/cac/{i}" for i in range(21)]
# # directories += [f"./svhn/ii/{i}" for i in range(21)]

directories += [f"./cifar100/mchad/{i}" for i in range(21)]
directories += [f"./cifar100/gmchad/{i}" for i in range(21)]
directories += [f"./cifar100/gcenter/{i}" for i in range(21)]
directories += [f"./cifar100/gcac/{i}" for i in range(21)]
directories += [f"./cifar100/cac/{i}" for i in range(21)]
directories += [f"./cifar100/ii/{i}" for i in range(21)]
directories += [f"./cifar100/center/{i}" for i in range(21)]


# # del directories[directories.index("./cifar100/cac/13")]
# # directories += [f"./cifar10/mchad/{i}" for i in range(21)]
# # directories += [f"./cifar10/center/{i}" for i in range(21)]
# directories += [f"./cifar10/gmchad/{i}" for i in range(21)]
# directories += [f"./cifar10/gcenter/{i}" for i in range(21)]
# directories += [f"./cifar10/gcac/{i}" for i in range(21)]
# # directories += [f"./cifar10/cac/{i}" for i in range(21)]
# # directories += [f"./cifar10/ii/{i}" for i in range(21)]

# %%
def get_training_set(datamodule):
    target = datamodule["_target_"]
    d = train_dataset_map.get(target)

    if not d:
        if target == "src.datamodules.MultiDatamodule":
            d = train_dataset_map.get(datamodule["module1"]["_target_"])

    if not d:
        print(datamodule)
    else:
        print(d)

    return d


def load(path):
    local_df = []

    df = pd.read_csv(join(path, "results.csv"))
    metrics = pd.read_csv(join(path, "csv/version_0/metrics.csv"))
    config = OmegaConf.load(join(path, "tb/version_0/hparams.yaml"))
    df["Dataset"] = get_training_set(config["datamodule"])
    df["Outliers"] = df["test_case_name"].apply(dataset_map.get)
    model = str(config["model"]["_target_"])

    if model == "src.models.CAC":
        df["Model"] = "CAC"
        df = convert(df, "Distance")
    elif model == "src.models.SoftMax":
        print("EB-OOD")
        df_ebm = df.copy(deep=True)
        df_ebm["Model"] = "EB-OOD"
        df_emb = convert(df_ebm, "EnergyBased")

        local_df.append(df_ebm)

        print("Softmax")
        df["Model"] = "Softmax"
        df = convert(df, "Softmax")

    elif model == "src.models.MCHAD":
        if config["model"]["weight_oe"] == 0.0:
            # print(f"Weight OE: {config['model']['weight_oe']}")
            df["Model"] = "MCHAD"
        else:
            print(f"Weight OE: {config['model']['weight_oe']}")
            df["Model"] = "G-MCHAD"

        df = convert(df)
    elif model == "src.models.Center":
        df["Model"] = "Center"
        df = convert(df, "Distance")
    elif model == "src.models.IIModel":
        df["Model"] = "II"
        df = convert(df)
    elif model == "src.models.GCenter":
        df["Model"] = "G-Center"
        df = convert(df, key="Distance")
    elif model == "src.models.GCAC":
        df["Model"] = "G-CAC"
        df = convert(df, key="Distance")
    else:
        raise Exception(f"UNKNOWN: {model}")

    local_df.append(df)
    return config, pd.concat(local_df), metrics

# %%
dfs = []

for d in directories:
    # filter(lambda x: "center" not in x and "cifar100/softmax/" not in x and "mchad-o" not in x, directories):
    path = join(root, d)
    config, df, metrics = load(path)
    try:
        if df is not None:
            print(path)
            print(
                f"{df['Dataset'][0]}/{df['Model'][0]} -> {df['AUROC'].mean()} {len(df)}"
            )
            df = df[
                [
                    "Accuracy",
                    "AUROC",
                    "AUPR-IN",
                    "AUPR-OUT",
                    "FPR95",
                    "Dataset",
                    "Outliers",
                    "Model",
                ]
            ]
            dfs.append(df.copy())
    except Exception as e:
        print("EXCEPTION WHILE LOADING")
        print(type(e), e)
        print(df.columns)

df = pd.concat(dfs)
# Out:
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/0
# CIFAR100/MCHAD -> 0.7253389284014702 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/1
# CIFAR100/MCHAD -> 0.7668203935027122 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/2
# CIFAR100/MCHAD -> 0.6603121906518936 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/3
# CIFAR100/MCHAD -> 0.7040302082896233 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/4
# CIFAR100/MCHAD -> 0.7366498336195946 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/5
# CIFAR100/MCHAD -> 0.7404263019561768 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/6
# CIFAR100/MCHAD -> 0.7167713642120361 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/7
# CIFAR100/MCHAD -> 0.7340620160102844 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/8
# CIFAR100/MCHAD -> 0.6930366680026054 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/9
# CIFAR100/MCHAD -> 0.6893847435712814 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/10
# CIFAR100/MCHAD -> 0.5845408886671066 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/11
# CIFAR100/MCHAD -> 0.7477521747350693 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/12
# CIFAR100/MCHAD -> 0.6058543771505356 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/13
# CIFAR100/MCHAD -> 0.7170287072658539 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/14
# CIFAR100/MCHAD -> 0.6127352826297283 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/15
# CIFAR100/MCHAD -> 0.6885716691613197 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/16
# CIFAR100/MCHAD -> 0.7608391121029854 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/17
# CIFAR100/MCHAD -> 0.6731840074062347 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/18
# CIFAR100/MCHAD -> 0.7325809821486473 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/19
# CIFAR100/MCHAD -> 0.7038001492619514 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/mchad/20
# CIFAR100/MCHAD -> 0.6820188611745834 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/0
# CIFAR100/G-MCHAD -> 0.7212091237306595 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/1
# CIFAR100/G-MCHAD -> 0.6658125892281532 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/2
# CIFAR100/G-MCHAD -> 0.7545212879776955 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/3
# CIFAR100/G-MCHAD -> 0.6911359578371048 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/4
# CIFAR100/G-MCHAD -> 0.6418293714523315 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/5
# CIFAR100/G-MCHAD -> 0.7707138881087303 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/6
# CIFAR100/G-MCHAD -> 0.7228900268673897 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/7
# CIFAR100/G-MCHAD -> 0.7276915535330772 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/8
# CIFAR100/G-MCHAD -> 0.786617137491703 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/9
# CIFAR100/G-MCHAD -> 0.7461877912282944 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/10
# CIFAR100/G-MCHAD -> 0.7464744821190834 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/11
# CIFAR100/G-MCHAD -> 0.7377259880304337 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/12
# CIFAR100/G-MCHAD -> 0.7860131561756134 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/13
# CIFAR100/G-MCHAD -> 0.6962995529174805 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/14
# CIFAR100/G-MCHAD -> 0.6945381537079811 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/15
# CIFAR100/G-MCHAD -> 0.7171455770730972 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/16
# CIFAR100/G-MCHAD -> 0.725610688328743 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/17
# CIFAR100/G-MCHAD -> 0.7433085143566132 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/18
# CIFAR100/G-MCHAD -> 0.739882193505764 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/19
# CIFAR100/G-MCHAD -> 0.7412113025784492 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gmchad/20
# CIFAR100/G-MCHAD -> 0.7598065659403801 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/0
# CIFAR100/G-Center -> 0.5405023004859686 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/1
# CIFAR100/G-Center -> 0.5139587670564651 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/2
# CIFAR100/G-Center -> 0.2949296832084656 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/3
# CIFAR100/G-Center -> 0.4582937341183424 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/4
# CIFAR100/G-Center -> 0.44175613205879927 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/5
# CIFAR100/G-Center -> 0.5363612314686179 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/6
# CIFAR100/G-Center -> 0.4994647325947881 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/7
# CIFAR100/G-Center -> 0.49781184177845716 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/8
# CIFAR100/G-Center -> 0.5718654170632362 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/9
# CIFAR100/G-Center -> 0.3883167989552021 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/10
# CIFAR100/G-Center -> 0.35288007371127605 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/11
# CIFAR100/G-Center -> 0.5181675106287003 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/12
# CIFAR100/G-Center -> 0.5397542677819729 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/13
# CIFAR100/G-Center -> 0.3255351362749934 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/14
# CIFAR100/G-Center -> 0.5025950837880373 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/15
# CIFAR100/G-Center -> 0.4449237687513232 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/16
# CIFAR100/G-Center -> 0.4867331627756357 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/17
# CIFAR100/G-Center -> 0.48812021501362324 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/18
# CIFAR100/G-Center -> 0.49431227520108223 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/19
# CIFAR100/G-Center -> 0.34972207993268967 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcenter/20
# CIFAR100/G-Center -> 0.550075220875442 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/0
# CIFAR100/G-CAC -> 0.4337598495185375 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/1
# CIFAR100/G-CAC -> 0.5347010567784309 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/2
# CIFAR100/G-CAC -> 0.4277632161974907 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/3
# CIFAR100/G-CAC -> 0.49026672914624214 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/4
# CIFAR100/G-CAC -> 0.4091033888980746 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/5
# CIFAR100/G-CAC -> 0.6585315316915512 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/6
# CIFAR100/G-CAC -> 0.43707364797592163 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/7
# CIFAR100/G-CAC -> 0.38422687724232674 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/8
# CIFAR100/G-CAC -> 0.33382321801036596 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/9
# CIFAR100/G-CAC -> 0.5839322805404663 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/10
# CIFAR100/G-CAC -> 0.5821912363171577 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/11
# CIFAR100/G-CAC -> 0.46456296369433403 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/12
# CIFAR100/G-CAC -> 0.4370053671300411 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/13
# CIFAR100/G-CAC -> 0.5998451858758926 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/14
# CIFAR100/G-CAC -> 0.33269290812313557 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/15
# CIFAR100/G-CAC -> 0.6025963611900806 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/16
# CIFAR100/G-CAC -> 0.5341426692903042 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/17
# CIFAR100/G-CAC -> 0.5357272885739803 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/18
# CIFAR100/G-CAC -> 0.5784672275185585 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/19
# CIFAR100/G-CAC -> 0.3768358379602432 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/gcac/20
# CIFAR100/G-CAC -> 0.5566277429461479 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/0
# CIFAR100/CAC -> 0.6492630839347839 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/1
# CIFAR100/CAC -> 0.4382314868271351 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/2
# CIFAR100/CAC -> 0.620937705039978 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/3
# CIFAR100/CAC -> 0.4874402619898319 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/4
# CIFAR100/CAC -> 0.5065355654805899 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/5
# CIFAR100/CAC -> 0.4974873624742031 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/6
# CIFAR100/CAC -> 0.5940177217125893 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/7
# CIFAR100/CAC -> 0.5709710344672203 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/8
# CIFAR100/CAC -> 0.6137369871139526 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/9
# CIFAR100/CAC -> 0.40550421737134457 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/10
# CIFAR100/CAC -> 0.45177130587399006 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/11
# CIFAR100/CAC -> 0.4027886362746358 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/12
# CIFAR100/CAC -> 0.5716179609298706 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/13
# CIFAR100/CAC -> 0.5301158130168915 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/14
# CIFAR100/CAC -> 0.6142862215638161 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/15
# CIFAR100/CAC -> 0.5183162912726402 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/16
# CIFAR100/CAC -> 0.386379468254745 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/17
# CIFAR100/CAC -> 0.5784272477030754 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/18
# CIFAR100/CAC -> 0.4629509365186095 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/19
# CIFAR100/CAC -> 0.6401387080550194 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/cac/20
# CIFAR100/CAC -> 0.5933301821351051 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/0
# CIFAR100/II -> 0.39137162268161774 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/1
# CIFAR100/II -> 0.3736949199810624 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/2
# CIFAR100/II -> 0.5451216027140617 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/3
# CIFAR100/II -> 0.5140116587281227 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/4
# CIFAR100/II -> 0.5693958550691605 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/5
# CIFAR100/II -> 0.2832881750073284 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/6
# CIFAR100/II -> 0.5406422652304173 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/7
# CIFAR100/II -> 0.5299316346645355 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/8
# CIFAR100/II -> 0.3911231365054846 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/9
# CIFAR100/II -> 0.48405394330620766 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/10
# CIFAR100/II -> 0.4298366978764534 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/11
# CIFAR100/II -> 0.46336472779512405 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/12
# CIFAR100/II -> 0.4229840971529484 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/13
# CIFAR100/II -> 0.534123633056879 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/14
# CIFAR100/II -> 0.4605526067316532 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/15
# CIFAR100/II -> 0.5566174313426018 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/16
# CIFAR100/II -> 0.5582472272217274 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/17
# CIFAR100/II -> 0.5458896718919277 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/18
# CIFAR100/II -> 0.45076948776841164 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/19
# CIFAR100/II -> 0.4094736110419035 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/ii/20
# CIFAR100/II -> 0.44006092473864555 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/0
# CIFAR100/Center -> 0.45969827473163605 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/1
# CIFAR100/Center -> 0.467956006526947 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/2
# CIFAR100/Center -> 0.5927864257246256 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/3
# CIFAR100/Center -> 0.37807493284344673 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/4
# CIFAR100/Center -> 0.5550557971000671 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/5
# CIFAR100/Center -> 0.5560815222561359 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/6
# CIFAR100/Center -> 0.5151852127164602 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/7
# CIFAR100/Center -> 0.5816274844110012 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/8
# CIFAR100/Center -> 0.5701050609350204 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/9
# CIFAR100/Center -> 0.34409516863524914 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/10
# CIFAR100/Center -> 0.5384302753955126 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/11
# CIFAR100/Center -> 0.5675479229539633 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/12
# CIFAR100/Center -> 0.4480759873986244 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/13
# CIFAR100/Center -> 0.5017236955463886 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/14
# CIFAR100/Center -> 0.5018966570496559 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/15
# CIFAR100/Center -> 0.5307570435106754 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/16
# CIFAR100/Center -> 0.5815731193870306 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/17
# CIFAR100/Center -> 0.5042490661144257 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/18
# CIFAR100/Center -> 0.5418881084769964 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/19
# CIFAR100/Center -> 0.3663678150624037 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-10:32:51/./cifar100/center/20
# CIFAR100/Center -> 0.5680673345923424 8

# %%
df["AUROC"] = df["AUROC"].apply(lambda x: x * 100)
df["AUPR-IN"] = df["AUPR-IN"].apply(lambda x: x * 100)
df["AUPR-OUT"] = df["AUPR-OUT"].apply(lambda x: x * 100)
df["FPR95"] = df["FPR95"].apply(lambda x: x * 100)
df["Accuracy"] = df["Accuracy"].apply(lambda x: x * 100)

# %%
# , "Tiny Crop", "LSUN Crop"
# df = df[df["Outliers"].isin(["Texture", "Tiny Resize", "LSUN Resize", "Uniform", "Gaussian"])]
df = df.set_index(["Dataset", "Outliers", "Model"]).dropna()

# %%
from itertools import product
datasets = ["SVHN", "CIFAR10", "CIFAR100"]
# models = ["CAC", "II", "Center", "Softmax", "EB-OOD", "MCHAD", "G-MCHAD"]
models = ["MCHAD", "II", "CAC", "Center", "G-MCHAD", "G-Center", "G-CAC"]

t =  df.reset_index().groupby(by=["Dataset", "Model"]).agg(
        {
            "Accuracy": ["mean", "sem"],
            "AUROC": ["mean", "sem"],
            "AUPR-IN": ["mean", "sem"],
            "AUPR-OUT": ["mean", "sem"],
            "FPR95": ["mean", "sem"],
        }
    ).reindex(list(product(datasets, models)))

s = t.to_latex(
        float_format="%.2f",
        multirow=True,
        escape=False,
        label="tab:results",
        # bold_rows="True",
    )

repl = {
    "mean": "Mean",
    "sem": "$\\pm \sigma_{\\bar{x}}$",
    " MCHAD": " \\textbf{MCHAD (ours)}",
    "G-MCHAD": "\\textbf{G-MCHAD (ours)}",
    "G-Center": "\\textbf{G-Center (ours)}",
    "G-CAC": "\\textbf{G-CAC (ours)}",
}

for k, v in repl.items():
    s = s.replace(k, v)

print(s)
# Out:
# \begin{table}
# \centering
# \label{tab:results}
# \begin{tabular}{llrrrrrrrrrr}
# \toprule
#          &       & \multicolumn{2}{l}{Accuracy} & \multicolumn{2}{l}{AUROC} & \multicolumn{2}{l}{AUPR-IN} & \multicolumn{2}{l}{AUPR-OUT} & \multicolumn{2}{l}{FPR95} \\
#          &       &     Mean &  $\pm \sigma_{\bar{x}}$ &  Mean &  $\pm \sigma_{\bar{x}}$ &    Mean &  $\pm \sigma_{\bar{x}}$ &     Mean &  $\pm \sigma_{\bar{x}}$ &  Mean &  $\pm \sigma_{\bar{x}}$ \\
# Dataset & Model &          &      &       &      &         &      &          &      &       &      \\
# \midrule
# \multirow{7}{*}{SVHN} & \textbf{MCHAD (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & II &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & CAC &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & Center &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-MCHAD (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-Center (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-CAC (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
# \cline{1-12}
# \multirow{7}{*}{CIFAR10} & \textbf{MCHAD (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & II &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & CAC &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & Center &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-MCHAD (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-Center (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-CAC (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
# \cline{1-12}
# \multirow{7}{*}{CIFAR100} & \textbf{MCHAD (ours)} &    77.56 & 0.02 & 79.87 & 1.05 &   72.60 & 1.16 &    84.30 & 0.86 & 47.74 & 2.10 \\
#          & II &     6.07 & 0.05 & 53.85 & 1.52 &   53.44 & 1.29 &    57.67 & 1.39 & 84.27 & 2.10 \\
#          & CAC &    61.06 & 0.18 & 60.59 & 1.60 &   58.06 & 1.33 &    67.32 & 1.16 & 74.99 & 1.78 \\
#          & Center &    77.44 & 0.02 & 58.07 & 2.14 &   56.42 & 1.47 &    67.14 & 1.75 & 69.15 & 2.13 \\
#          & \textbf{G-MCHAD (ours)} &    77.12 & 0.02 & 83.36 & 0.97 &   79.73 & 1.07 &    85.79 & 0.90 & 46.00 & 2.41 \\
#          & \textbf{G-Center (ours)} &    76.17 & 0.02 & 53.31 & 2.50 &   55.59 & 1.60 &    63.56 & 1.89 & 74.05 & 1.92 \\
#          & \textbf{G-CAC (ours)} &    34.05 & 1.70 & 56.02 & 1.65 &   54.83 & 1.41 &    64.12 & 1.20 & 77.04 & 1.78 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
methods = ["MCHAD", "II", "CAC", "Center", "G-MCHAD", "G-Center", "G-CAC"]
# ,
for dataset in [ "CIFAR100"]:
    g = sb.catplot(
        data=df.reset_index()[df.reset_index()["Dataset"] == dataset],
        x="Outliers",
        y="AUROC",
        kind="bar",
        hue="Model",
        col="Dataset",
        hue_order=methods
    )
    g.set_xticklabels(rotation=30)
    plt.savefig(f"out/single-auroc-{dataset}.png", dpi=300)
    plt.show()

# %%
tmp = df.reset_index().copy()
# tmp = tmp[(tmp["Model"] == "MCHAD") | (tmp["Model"] == "G-MCHAD")| (tmp["Model"] == "G-CAC") | (tmp["Model"] == "G-Center")]

print(
    tmp
    .groupby(by=["Dataset", "Model"])
    .agg(
        {
            "Accuracy": ["mean", "sem"],
            "AUROC": ["mean", "sem"],
            "AUPR-IN": ["mean", "sem"],
            "AUPR-OUT": ["mean", "sem"],
            "FPR95": ["mean", "sem"],
        }
    )
    .to_html(
        float_format="%.2f",
        escape=False,
    )
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">Accuracy</th>
#       <th colspan="2" halign="left">AUROC</th>
#       <th colspan="2" halign="left">AUPR-IN</th>
#       <th colspan="2" halign="left">AUPR-OUT</th>
#       <th colspan="2" halign="left">FPR95</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#     </tr>
#     <tr>
#       <th>Dataset</th>
#       <th>Model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="7" valign="top">CIFAR100</th>
#       <th>CAC</th>
#       <td>61.06</td>
#       <td>0.18</td>
#       <td>60.59</td>
#       <td>1.60</td>
#       <td>58.06</td>
#       <td>1.33</td>
#       <td>67.32</td>
#       <td>1.16</td>
#       <td>74.99</td>
#       <td>1.78</td>
#     </tr>
#     <tr>
#       <th>Center</th>
#       <td>77.44</td>
#       <td>0.02</td>
#       <td>58.07</td>
#       <td>2.14</td>
#       <td>56.42</td>
#       <td>1.47</td>
#       <td>67.14</td>
#       <td>1.75</td>
#       <td>69.15</td>
#       <td>2.13</td>
#     </tr>
#     <tr>
#       <th>G-CAC</th>
#       <td>34.05</td>
#       <td>1.70</td>
#       <td>56.02</td>
#       <td>1.65</td>
#       <td>54.83</td>
#       <td>1.41</td>
#       <td>64.12</td>
#       <td>1.20</td>
#       <td>77.04</td>
#       <td>1.78</td>
#     </tr>
#     <tr>
#       <th>G-Center</th>
#       <td>76.17</td>
#       <td>0.02</td>
#       <td>53.31</td>
#       <td>2.50</td>
#       <td>55.59</td>
#       <td>1.60</td>
#       <td>63.56</td>
#       <td>1.89</td>
#       <td>74.05</td>
#       <td>1.92</td>
#     </tr>
#     <tr>
#       <th>G-MCHAD</th>
#       <td>77.12</td>
#       <td>0.02</td>
#       <td>83.36</td>
#       <td>0.97</td>
#       <td>79.73</td>
#       <td>1.07</td>
#       <td>85.79</td>
#       <td>0.90</td>
#       <td>46.00</td>
#       <td>2.41</td>
#     </tr>
#     <tr>
#       <th>II</th>
#       <td>6.07</td>
#       <td>0.05</td>
#       <td>53.85</td>
#       <td>1.52</td>
#       <td>53.44</td>
#       <td>1.29</td>
#       <td>57.67</td>
#       <td>1.39</td>
#       <td>84.27</td>
#       <td>2.10</td>
#     </tr>
#     <tr>
#       <th>MCHAD</th>
#       <td>77.56</td>
#       <td>0.02</td>
#       <td>79.87</td>
#       <td>1.05</td>
#       <td>72.60</td>
#       <td>1.16</td>
#       <td>84.30</td>
#       <td>0.86</td>
#       <td>47.74</td>
#       <td>2.10</td>
#     </tr>
#   </tbody>
# </table>

# %%
tmp.groupby(by=["Dataset", "Model"]).agg(
    {
        "Accuracy": ["mean", "sem"],
        "AUROC": ["mean", "sem"],
        "AUPR-IN": ["mean", "sem"],
        "AUPR-OUT": ["mean", "sem"],
        "FPR95": ["mean", "sem"],
    }
)
# Out:
#                     Accuracy                AUROC              AUPR-IN  \
#                         mean       sem       mean       sem       mean
# Dataset  Model
# CIFAR100 CAC       61.058095  0.182948  60.594548  1.598202  58.055284
#          Center    77.441429  0.017806  58.074791  2.139484  56.423837
#          G-CAC     34.048095  1.695116  56.021097  1.650674  54.832737
#          G-Center  76.167143  0.021422  53.311997  2.504981  55.588027
#          G-MCHAD   77.118572  0.020426  83.355782  0.970197  79.726734
#          II         6.069048  0.050953  53.847918  1.523707  53.435751
#          MCHAD     77.562857  0.018931  79.867967  1.048487  72.596034
#
#                               AUPR-OUT                FPR95
#                         sem       mean       sem       mean       sem
# Dataset  Model
# CIFAR100 CAC       1.331398  67.319347  1.163167  74.986327  1.782222
#          Center    1.465647  67.143658  1.745458  69.151429  2.132654
#          G-CAC     1.414681  64.117978  1.201753  77.040476  1.781699
#          G-Center  1.598618  63.561303  1.890124  74.047483  1.922901
#          G-MCHAD   1.071659  85.794238  0.897230  46.004898  2.414409
#          II        1.292917  57.671541  1.392272  84.268231  2.101209
#          MCHAD     1.156673  84.300835  0.856714  47.737755  2.095442

# %%
from scipy.stats import ttest_ind

tmp = df.reset_index().copy()
# tmp = tmp[(tmp["Model"] == "MCHAD") | (tmp["Model"] == "G-MCHAD")]

for metric in ["Accuracy", "AUROC", "AUPR-IN", "AUPR-OUT", "FPR95"]:
    for dataset in ["SVHN", "CIFAR10", "CIFAR100"]:
        a = tmp[(tmp["Model"] == "CAC") & (tmp["Dataset"] == dataset)][metric]
        b = tmp[(tmp["Model"] == "MCHAD") & (tmp["Dataset"]== dataset)][metric]
        stat, p = ttest_ind(a,b, equal_var=False)
        print(f"{metric} {dataset} -> {p < 0.05} ")
# Out:
# Accuracy SVHN -> False
# Accuracy CIFAR10 -> False
# Accuracy CIFAR100 -> True
# AUROC SVHN -> False
# AUROC CIFAR10 -> False
# AUROC CIFAR100 -> True
# AUPR-IN SVHN -> False
# AUPR-IN CIFAR10 -> False
# AUPR-IN CIFAR100 -> True
# AUPR-OUT SVHN -> False
# AUPR-OUT CIFAR10 -> False
# AUPR-OUT CIFAR100 -> True
# FPR95 SVHN -> False
# FPR95 CIFAR10 -> False
# FPR95 CIFAR100 -> True

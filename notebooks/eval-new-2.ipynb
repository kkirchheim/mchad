# %% [markdown]
# ## Generate Result Tables
# - MCHAD
# - CAC
# - II
# - Center Loss
# - G-MCHAD
# - G-Center
# - G-CAC

# %%
import seaborn as sb
import matplotlib.pyplot as plt
from omegaconf import OmegaConf
import pandas as pd
from os.path import join

# %%
sb.set()
sb.set_style("whitegrid")
sb.set_context("paper")

# %%
# root folder for experiment run
root = "/home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/"

# %%
# map test cases
dataset_map = {
    "test_vs_uniformnoise": "Uniform",
    "test_vs_gaussiannoise": "Gaussian",
    "test_vs_tinycrop": "Tiny Crop",
    "test_vs_tinyresize": "Tiny Resize",
    "test_vs_lsuncrop": "LSUN Crop",
    "test_vs_lsunresize": "LSUN Resize",
    "test_vs_textures": "Texture",
}

model_map = {
    "src.models.CAC": "CAC",
    "src.models.Softmax": "Softmax",
    "src.models.MCHAD": "MCHAD",
    "src.models.Center": "Center",
    "src.models.II": "II",
    "src.models.GCAC": "G-CAC",
    "src.models.GCenter": "G-Center",
}


train_dataset_map = {
    "src.datamodules.CIFAR10DataModule": "CIFAR10",
    "src.datamodules.SVHNDataModule": "SVHN",
    "src.datamodules.CIFAR100DataModule": "CIFAR100",
}

# %%
def convert(df, key="Distance", task="OOD"):
    """
    Get correct metrics from dataframe
    """
    df.rename(
        inplace=True,
        columns={
            "Accuracy/test": "Accuracy",
            f"{key}/{task}/AUROC/test": "AUROC",
            f"{key}/{task}/AUPR-IN/test": "AUPR-IN",
            f"{key}/{task}/AUPR-OUT/test": "AUPR-OUT",
            f"{key}/{task}/FPR95TPR/test": "FPR95",
        },
    )

    return df

# %%
directories = []
# directories += [f"./svhn/center/{i}" for i in range(21)]
# directories += [f"./svhn/mchad/{i}" for i in range(21)]
directories += [f"./svhn/gmchad/{i}" for i in range(21)]
directories += [f"./svhn/gcenter/{i}" for i in range(21)]
directories += [f"./svhn/gcac/{i}" for i in range(21)]
# directories += [f"./svhn/cac/{i}" for i in range(21)]
# directories += [f"./svhn/ii/{i}" for i in range(21)]

# directories += [f"./cifar100/mchad/{i}" for i in range(21)]
directories += [f"./cifar100/gmchad/{i}" for i in range(21)]
directories += [f"./cifar100/gcenter/{i}" for i in range(21)]
directories += [f"./cifar100/gcac/{i}" for i in range(21)]
# directories += [f"./cifar100/cac/{i}" for i in range(21)]
# directories += [f"./cifar100/ii/{i}" for i in range(21)]
# directories += [f"./cifar100/center/{i}" for i in range(21)]


# del directories[directories.index("./cifar100/cac/13")]
# directories += [f"./cifar10/mchad/{i}" for i in range(21)]
# directories += [f"./cifar10/center/{i}" for i in range(21)]
directories += [f"./cifar10/gmchad/{i}" for i in range(21)]
directories += [f"./cifar10/gcenter/{i}" for i in range(21)]
directories += [f"./cifar10/gcac/{i}" for i in range(21)]
# directories += [f"./cifar10/cac/{i}" for i in range(21)]
# directories += [f"./cifar10/ii/{i}" for i in range(21)]

# %%
def get_training_set(datamodule):
    target = datamodule["_target_"]
    d = train_dataset_map.get(target)

    if not d:
        if target == "src.datamodules.MultiDatamodule":
            d = train_dataset_map.get(datamodule["module1"]["_target_"])

    if not d:
        print(datamodule)
    else:
        print(d)

    return d


def load(path):
    local_df = []

    df = pd.read_csv(join(path, "results.csv"))
    metrics = pd.read_csv(join(path, "csv/version_0/metrics.csv"))
    config = OmegaConf.load(join(path, "tb/version_0/hparams.yaml"))
    df["Dataset"] = get_training_set(config["datamodule"])
    df["Outliers"] = df["test_case_name"].apply(dataset_map.get)
    model = str(config["model"]["_target_"])

    if model == "src.models.CAC":
        df["Model"] = "CAC"
        df = convert(df, "Distance")
    elif model == "src.models.SoftMax":
        print("EB-OOD")
        df_ebm = df.copy(deep=True)
        df_ebm["Model"] = "EB-OOD"
        df_emb = convert(df_ebm, "EnergyBased")

        local_df.append(df_ebm)

        print("Softmax")
        df["Model"] = "Softmax"
        df = convert(df, "Softmax")

    elif model == "src.models.MCHAD":
        if config["model"]["weight_oe"] == 0.0:
            # print(f"Weight OE: {config['model']['weight_oe']}")
            df["Model"] = "MCHAD"
        else:
            print(f"Weight OE: {config['model']['weight_oe']}")
            df["Model"] = "G-MCHAD"

        df = convert(df)
    elif model == "src.models.Center":
        df["Model"] = "Center"
        df = convert(df, "Distance")
    elif model == "src.models.IIModel":
        df["Model"] = "II"
        df = convert(df)
    elif model == "src.models.GCenter":
        df["Model"] = "G-Center"
        df = convert(df, key="Distance")
    elif model == "src.models.GCAC":
        df["Model"] = "G-CAC"
        df = convert(df, key="Distance")
    else:
        raise Exception(f"UNKNOWN: {model}")

    local_df.append(df)
    return config, pd.concat(local_df), metrics

# %%
dfs = []

for d in directories:
    # filter(lambda x: "center" not in x and "cifar100/softmax/" not in x and "mchad-o" not in x, directories):
    path = join(root, d)
    config, df, metrics = load(path)
    try:
        if df is not None:
            print(path)
            print(
                f"{df['Dataset'][0]}/{df['Model'][0]} -> {df['AUROC'].mean()} {len(df)}"
            )
            df = df[
                [
                    "Accuracy",
                    "AUROC",
                    "AUPR-IN",
                    "AUPR-OUT",
                    "FPR95",
                    "Dataset",
                    "Outliers",
                    "Model",
                ]
            ]
            dfs.append(df.copy())
    except Exception as e:
        print("EXCEPTION WHILE LOADING")
        print(type(e), e)
        print(df.columns)

df = pd.concat(dfs)
# Out:
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/0
# SVHN/G-MCHAD -> 0.8701320290565491 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/1
# SVHN/G-MCHAD -> 0.868304155766964 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/2
# SVHN/G-MCHAD -> 0.8687572628259659 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/3
# SVHN/G-MCHAD -> 0.86908358335495 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/4
# SVHN/G-MCHAD -> 0.8715425953269005 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/5
# SVHN/G-MCHAD -> 0.8708426803350449 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/6
# SVHN/G-MCHAD -> 0.8699737712740898 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/7
# SVHN/G-MCHAD -> 0.8671398013830185 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/8
# SVHN/G-MCHAD -> 0.8682891204953194 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/9
# SVHN/G-MCHAD -> 0.8724460527300835 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/10
# SVHN/G-MCHAD -> 0.8694129660725594 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/11
# SVHN/G-MCHAD -> 0.8703067675232887 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/12
# SVHN/G-MCHAD -> 0.8657308891415596 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/13
# SVHN/G-MCHAD -> 0.868300087749958 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/14
# SVHN/G-MCHAD -> 0.8670292273163795 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/15
# SVHN/G-MCHAD -> 0.8712601587176323 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/16
# SVHN/G-MCHAD -> 0.8699377626180649 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/17
# SVHN/G-MCHAD -> 0.868783675134182 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/18
# SVHN/G-MCHAD -> 0.8698750659823418 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/19
# SVHN/G-MCHAD -> 0.8718058988451958 8
# SVHN
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gmchad/20
# SVHN/G-MCHAD -> 0.8652166351675987 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/0
# SVHN/G-Center -> 0.8641857281327248 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/1
# SVHN/G-Center -> 0.8687370643019676 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/2
# SVHN/G-Center -> 0.8702825829386711 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/3
# SVHN/G-Center -> 0.8687871769070625 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/4
# SVHN/G-Center -> 0.8685116842389107 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/5
# SVHN/G-Center -> 0.8700165003538132 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/6
# SVHN/G-Center -> 0.8643748462200165 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/7
# SVHN/G-Center -> 0.8710469529032707 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/8
# SVHN/G-Center -> 0.8685346841812134 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/9
# SVHN/G-Center -> 0.8713626489043236 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/10
# SVHN/G-Center -> 0.8710122257471085 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/11
# SVHN/G-Center -> 0.8708032369613647 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/12
# SVHN/G-Center -> 0.8709727898240089 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/13
# SVHN/G-Center -> 0.8665876090526581 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/14
# SVHN/G-Center -> 0.868393748998642 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/15
# SVHN/G-Center -> 0.867145374417305 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/16
# SVHN/G-Center -> 0.870254211127758 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/17
# SVHN/G-Center -> 0.8725325539708138 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/18
# SVHN/G-Center -> 0.8714275062084198 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/19
# SVHN/G-Center -> 0.8705421909689903 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcenter/20
# SVHN/G-Center -> 0.8633240610361099 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/0
# SVHN/G-CAC -> 0.865509532392025 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/1
# SVHN/G-CAC -> 0.8636042699217796 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/2
# SVHN/G-CAC -> 0.8684180080890656 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/3
# SVHN/G-CAC -> 0.8652787059545517 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/4
# SVHN/G-CAC -> 0.863543838262558 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/5
# SVHN/G-CAC -> 0.866731695830822 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/6
# SVHN/G-CAC -> 0.8646138086915016 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/7
# SVHN/G-CAC -> 0.8634837120771408 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/8
# SVHN/G-CAC -> 0.8627557456493378 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/9
# SVHN/G-CAC -> 0.8649988770484924 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/10
# SVHN/G-CAC -> 0.866404302418232 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/11
# SVHN/G-CAC -> 0.8616607785224915 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/12
# SVHN/G-CAC -> 0.8601121976971626 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/13
# SVHN/G-CAC -> 0.8617377877235413 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/14
# SVHN/G-CAC -> 0.863492451608181 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/15
# SVHN/G-CAC -> 0.8647796511650085 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/16
# SVHN/G-CAC -> 0.8656663969159126 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/17
# SVHN/G-CAC -> 0.8677029386162758 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/18
# SVHN/G-CAC -> 0.8612547367811203 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/19
# SVHN/G-CAC -> 0.8671400398015976 8
# SVHN
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./svhn/gcac/20
# SVHN/G-CAC -> 0.8680414110422134 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/0
# CIFAR100/G-MCHAD -> 0.5656591504812241 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/1
# CIFAR100/G-MCHAD -> 0.7000810652971268 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/2
# CIFAR100/G-MCHAD -> 0.5951670557260513 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/3
# CIFAR100/G-MCHAD -> 0.4928527604788542 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/4
# CIFAR100/G-MCHAD -> 0.7097329646348953 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/5
# CIFAR100/G-MCHAD -> 0.7122111767530441 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/6
# CIFAR100/G-MCHAD -> 0.5737157166004181 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/7
# CIFAR100/G-MCHAD -> 0.6830020025372505 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/8
# CIFAR100/G-MCHAD -> 0.7309922426939011 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/9
# CIFAR100/G-MCHAD -> 0.6573204696178436 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/10
# CIFAR100/G-MCHAD -> 0.5149998106062412 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/11
# CIFAR100/G-MCHAD -> 0.6892389133572578 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/12
# CIFAR100/G-MCHAD -> 0.7486267611384392 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/13
# CIFAR100/G-MCHAD -> 0.7364212647080421 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/14
# CIFAR100/G-MCHAD -> 0.5929148718714714 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/15
# CIFAR100/G-MCHAD -> 0.7077929973602295 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/16
# CIFAR100/G-MCHAD -> 0.7045846059918404 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/17
# CIFAR100/G-MCHAD -> 0.629281185567379 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/18
# CIFAR100/G-MCHAD -> 0.7394236475229263 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/19
# CIFAR100/G-MCHAD -> 0.7268306016921997 8
# CIFAR100
# Weight OE: 0.0005
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gmchad/20
# CIFAR100/G-MCHAD -> 0.7526477575302124 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/0
# CIFAR100/G-Center -> 0.5467107221484184 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/1
# CIFAR100/G-Center -> 0.5222727116197348 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/2
# CIFAR100/G-Center -> 0.47021891735494137 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/3
# CIFAR100/G-Center -> 0.3187256185337901 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/4
# CIFAR100/G-Center -> 0.48465196788311005 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/5
# CIFAR100/G-Center -> 0.4775022752583027 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/6
# CIFAR100/G-Center -> 0.4538341648876667 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/7
# CIFAR100/G-Center -> 0.4799990328028798 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/8
# CIFAR100/G-Center -> 0.4928810982964933 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/9
# CIFAR100/G-Center -> 0.48859902936965227 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/10
# CIFAR100/G-Center -> 0.39860194455832243 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/11
# CIFAR100/G-Center -> 0.5321099888533354 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/12
# CIFAR100/G-Center -> 0.45817460771650076 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/13
# CIFAR100/G-Center -> 0.4063344420865178 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/14
# CIFAR100/G-Center -> 0.3941217241808772 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/15
# CIFAR100/G-Center -> 0.5208526123315096 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/16
# CIFAR100/G-Center -> 0.27125509316101665 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/17
# CIFAR100/G-Center -> 0.4444626681506634 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/18
# CIFAR100/G-Center -> 0.4148387014865875 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/19
# CIFAR100/G-Center -> 0.5421881275251508 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcenter/20
# CIFAR100/G-Center -> 0.5285908691585064 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/0
# CIFAR100/G-CAC -> 0.5227865427732468 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/1
# CIFAR100/G-CAC -> 0.3498874641954899 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/2
# CIFAR100/G-CAC -> 0.475540641695261 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/3
# CIFAR100/G-CAC -> 0.4537252299487591 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/4
# CIFAR100/G-CAC -> 0.11947317235171792 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/5
# CIFAR100/G-CAC -> 0.5150519642047584 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/6
# CIFAR100/G-CAC -> 0.2971153296530247 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/7
# CIFAR100/G-CAC -> 0.1826317380182445 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/8
# CIFAR100/G-CAC -> 0.33748324029147625 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/9
# CIFAR100/G-CAC -> 0.4366169311106205 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/10
# CIFAR100/G-CAC -> 0.31268617883324623 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/11
# CIFAR100/G-CAC -> 0.4881308563053608 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/12
# CIFAR100/G-CAC -> 0.48453934118151665 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/13
# CIFAR100/G-CAC -> 0.530439343303442 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/14
# CIFAR100/G-CAC -> 0.20403308048844332 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/15
# CIFAR100/G-CAC -> 0.3673722301609814 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/16
# CIFAR100/G-CAC -> 0.3836178034543991 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/17
# CIFAR100/G-CAC -> 0.5401798859238625 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/18
# CIFAR100/G-CAC -> 0.578102357685566 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/19
# CIFAR100/G-CAC -> 0.3684386061504483 8
# CIFAR100
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar100/gcac/20
# CIFAR100/G-CAC -> 0.3712863160180859 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/0
# CIFAR10/G-MCHAD -> 0.854615829885006 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/1
# CIFAR10/G-MCHAD -> 0.8519862219691277 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/2
# CIFAR10/G-MCHAD -> 0.8289588987827301 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/3
# CIFAR10/G-MCHAD -> 0.8520806059241295 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/4
# CIFAR10/G-MCHAD -> 0.8525141403079033 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/5
# CIFAR10/G-MCHAD -> 0.8244509547948837 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/6
# CIFAR10/G-MCHAD -> 0.8582296669483185 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/7
# CIFAR10/G-MCHAD -> 0.8009158596396446 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/8
# CIFAR10/G-MCHAD -> 0.8330352604389191 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/9
# CIFAR10/G-MCHAD -> 0.8498587608337402 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/10
# CIFAR10/G-MCHAD -> 0.8549469485878944 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/11
# CIFAR10/G-MCHAD -> 0.8413335904479027 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/12
# CIFAR10/G-MCHAD -> 0.8219296038150787 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/13
# CIFAR10/G-MCHAD -> 0.8538940921425819 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/14
# CIFAR10/G-MCHAD -> 0.8518743067979813 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/15
# CIFAR10/G-MCHAD -> 0.8546935096383095 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/16
# CIFAR10/G-MCHAD -> 0.8184007331728935 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/17
# CIFAR10/G-MCHAD -> 0.8278404176235199 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/18
# CIFAR10/G-MCHAD -> 0.8561945334076881 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/19
# CIFAR10/G-MCHAD -> 0.8514953777194023 8
# CIFAR10
# Weight OE: 1e-05
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gmchad/20
# CIFAR10/G-MCHAD -> 0.8212459683418274 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/0
# CIFAR10/G-Center -> 0.830148309469223 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/1
# CIFAR10/G-Center -> 0.820148840546608 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/2
# CIFAR10/G-Center -> 0.7534021884202957 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/3
# CIFAR10/G-Center -> 0.8192348629236221 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/4
# CIFAR10/G-Center -> 0.8173258453607559 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/5
# CIFAR10/G-Center -> 0.7837901636958122 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/6
# CIFAR10/G-Center -> 0.8024570569396019 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/7
# CIFAR10/G-Center -> 0.8191587403416634 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/8
# CIFAR10/G-Center -> 0.8157457113265991 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/9
# CIFAR10/G-Center -> 0.7941366508603096 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/10
# CIFAR10/G-Center -> 0.7946964055299759 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/11
# CIFAR10/G-Center -> 0.8249100595712662 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/12
# CIFAR10/G-Center -> 0.820274755358696 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/13
# CIFAR10/G-Center -> 0.7966326177120209 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/14
# CIFAR10/G-Center -> 0.7757898196578026 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/15
# CIFAR10/G-Center -> 0.8238168954849243 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/16
# CIFAR10/G-Center -> 0.8235325664281845 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/17
# CIFAR10/G-Center -> 0.7767971977591515 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/18
# CIFAR10/G-Center -> 0.8214522525668144 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/19
# CIFAR10/G-Center -> 0.803496964275837 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcenter/20
# CIFAR10/G-Center -> 0.827838160097599 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/0
# CIFAR10/G-CAC -> 0.504530094563961 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/1
# CIFAR10/G-CAC -> 0.7637602686882019 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/2
# CIFAR10/G-CAC -> 0.4652765989303589 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/3
# CIFAR10/G-CAC -> 0.7922069281339645 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/4
# CIFAR10/G-CAC -> 0.7851141542196274 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/5
# CIFAR10/G-CAC -> 0.5506935324519873 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/6
# CIFAR10/G-CAC -> 0.6139089427888393 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/7
# CIFAR10/G-CAC -> 0.4142456352710724 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/8
# CIFAR10/G-CAC -> 0.782265730202198 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/9
# CIFAR10/G-CAC -> 0.5171685516834259 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/10
# CIFAR10/G-CAC -> 0.7953332364559174 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/11
# CIFAR10/G-CAC -> 0.4473297894001007 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/12
# CIFAR10/G-CAC -> 0.7655298709869385 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/13
# CIFAR10/G-CAC -> 0.7928610593080521 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/14
# CIFAR10/G-CAC -> 0.7972256913781166 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/15
# CIFAR10/G-CAC -> 0.771228015422821 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/16
# CIFAR10/G-CAC -> 0.7856891751289368 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/17
# CIFAR10/G-CAC -> 0.7984509542584419 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/18
# CIFAR10/G-CAC -> 0.7664657235145569 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/19
# CIFAR10/G-CAC -> 0.28970665857195854 8
# CIFAR10
# /home/ki/projects/work/mchad/logs/multiruns/22-12:38:34/./cifar10/gcac/20
# CIFAR10/G-CAC -> 0.32147871423512697 8

# %%
df["AUROC"] = df["AUROC"].apply(lambda x: x * 100)
df["AUPR-IN"] = df["AUPR-IN"].apply(lambda x: x * 100)
df["AUPR-OUT"] = df["AUPR-OUT"].apply(lambda x: x * 100)
df["FPR95"] = df["FPR95"].apply(lambda x: x * 100)
df["Accuracy"] = df["Accuracy"].apply(lambda x: x * 100)

# %%
# , "Tiny Crop", "LSUN Crop"
# df = df[df["Outliers"].isin(["Texture", "Tiny Resize", "LSUN Resize", "Uniform", "Gaussian"])]
df = df.set_index(["Dataset", "Outliers", "Model"]).dropna()

# %%
from itertools import product
datasets = ["SVHN", "CIFAR10", "CIFAR100"]
# models = ["CAC", "II", "Center", "Softmax", "EB-OOD", "MCHAD", "G-MCHAD"]
models = ["MCHAD", "II", "CAC", "Center", "G-MCHAD", "G-Center", "G-CAC"]

t =  df.reset_index().groupby(by=["Dataset", "Model"]).agg(
        {
            "Accuracy": ["mean", "sem"],
            "AUROC": ["mean", "sem"],
            "AUPR-IN": ["mean", "sem"],
            "AUPR-OUT": ["mean", "sem"],
            "FPR95": ["mean", "sem"],
        }
    ).reindex(list(product(datasets, models)))

s = t.to_latex(
        float_format="%.2f",
        multirow=True,
        escape=False,
        label="tab:results",
        # bold_rows="True",
    )

repl = {
    "mean": "Mean",
    "sem": "$\\pm \sigma_{\\bar{x}}$",
    " MCHAD": " \\textbf{MCHAD (ours)}",
    "G-MCHAD": "\\textbf{G-MCHAD (ours)}",
    "G-Center": "\\textbf{G-Center (ours)}",
    "G-CAC": "\\textbf{G-CAC (ours)}",
}

for k, v in repl.items():
    s = s.replace(k, v)

print(s)
# Out:
# \begin{table}
# \centering
# \label{tab:results}
# \begin{tabular}{llrrrrrrrrrr}
# \toprule
#          &       & \multicolumn{2}{l}{Accuracy} & \multicolumn{2}{l}{AUROC} & \multicolumn{2}{l}{AUPR-IN} & \multicolumn{2}{l}{AUPR-OUT} & \multicolumn{2}{l}{FPR95} \\
#          &       &     Mean &  $\pm \sigma_{\bar{x}}$ &  Mean &  $\pm \sigma_{\bar{x}}$ &    Mean &  $\pm \sigma_{\bar{x}}$ &     Mean &  $\pm \sigma_{\bar{x}}$ &  Mean &  $\pm \sigma_{\bar{x}}$ \\
# Dataset & Model &          &      &       &      &         &      &          &      &       &      \\
# \midrule
# \multirow{7}{*}{SVHN} & \textbf{MCHAD (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & II &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & CAC &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & Center &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-MCHAD (ours)} &    95.72 & 0.01 & 99.34 & 0.06 &   96.98 & 0.27 &    99.78 & 0.02 &  2.23 & 0.19 \\
#          & \textbf{G-Center (ours)} &    95.86 & 0.01 & 99.31 & 0.11 &   98.23 & 0.28 &    99.69 & 0.05 &  2.64 & 0.40 \\
#          & \textbf{G-CAC (ours)} &    94.24 & 0.03 & 98.81 & 0.18 &   97.92 & 0.30 &    99.17 & 0.13 &  5.61 & 0.98 \\
# \cline{1-12}
# \multirow{7}{*}{CIFAR10} & \textbf{MCHAD (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & II &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & CAC &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & Center &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-MCHAD (ours)} &    94.74 & 0.01 & 96.11 & 0.25 &   93.27 & 0.54 &    97.20 & 0.16 & 11.37 & 0.56 \\
#          & \textbf{G-Center (ours)} &    94.30 & 0.01 & 92.22 & 0.57 &   87.72 & 0.91 &    93.99 & 0.44 & 21.52 & 1.28 \\
#          & \textbf{G-CAC (ours)} &    71.84 & 2.69 & 73.58 & 1.96 &   73.20 & 1.77 &    74.31 & 1.57 & 65.69 & 2.77 \\
# \cline{1-12}
# \multirow{7}{*}{CIFAR100} & \textbf{MCHAD (ours)} &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & II &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & CAC &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & Center &      NaN &  NaN &   NaN &  NaN &     NaN &  NaN &      NaN &  NaN &   NaN &  NaN \\
#          & \textbf{G-MCHAD (ours)} &    75.50 & 0.03 & 75.99 & 1.46 &   71.29 & 1.41 &    80.98 & 1.12 & 52.99 & 2.29 \\
#          & \textbf{G-Center (ours)} &    71.05 & 0.04 & 52.50 & 2.58 &   54.42 & 1.57 &    63.35 & 1.91 & 73.36 & 2.26 \\
#          & \textbf{G-CAC (ours)} &     2.15 & 0.07 & 45.27 & 1.96 &   49.13 & 1.41 &    56.31 & 1.43 & 82.23 & 2.03 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
methods = ["MCHAD", "II", "CAC", "Center", "G-MCHAD", "G-Center", "G-CAC"]
# ,
for dataset in ["CIFAR10", "SVHN", "CIFAR100"]:
    g = sb.catplot(
        data=df.reset_index()[df.reset_index()["Dataset"] == dataset],
        x="Outliers",
        y="AUROC",
        kind="bar",
        hue="Model",
        col="Dataset",
        hue_order=methods
    )
    g.set_xticklabels(rotation=30)
    plt.savefig(f"out/single-auroc-{dataset}.png", dpi=300)
    plt.show()

# %%
tmp = df.reset_index().copy()
# tmp = tmp[(tmp["Model"] == "MCHAD") | (tmp["Model"] == "G-MCHAD")| (tmp["Model"] == "G-CAC") | (tmp["Model"] == "G-Center")]

print(
    tmp
    .groupby(by=["Dataset", "Model"])
    .agg(
        {
            "Accuracy": ["mean", "sem"],
            "AUROC": ["mean", "sem"],
            "AUPR-IN": ["mean", "sem"],
            "AUPR-OUT": ["mean", "sem"],
            "FPR95": ["mean", "sem"],
        }
    )
    .to_html(
        float_format="%.2f",
        escape=False,
    )
)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th colspan="2" halign="left">Accuracy</th>
#       <th colspan="2" halign="left">AUROC</th>
#       <th colspan="2" halign="left">AUPR-IN</th>
#       <th colspan="2" halign="left">AUPR-OUT</th>
#       <th colspan="2" halign="left">FPR95</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#       <th>mean</th>
#       <th>sem</th>
#     </tr>
#     <tr>
#       <th>Dataset</th>
#       <th>Model</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">CIFAR10</th>
#       <th>G-CAC</th>
#       <td>71.84</td>
#       <td>2.69</td>
#       <td>73.58</td>
#       <td>1.96</td>
#       <td>73.20</td>
#       <td>1.77</td>
#       <td>74.31</td>
#       <td>1.57</td>
#       <td>65.69</td>
#       <td>2.77</td>
#     </tr>
#     <tr>
#       <th>G-Center</th>
#       <td>94.30</td>
#       <td>0.01</td>
#       <td>92.22</td>
#       <td>0.57</td>
#       <td>87.72</td>
#       <td>0.91</td>
#       <td>93.99</td>
#       <td>0.44</td>
#       <td>21.52</td>
#       <td>1.28</td>
#     </tr>
#     <tr>
#       <th>G-MCHAD</th>
#       <td>94.74</td>
#       <td>0.01</td>
#       <td>96.11</td>
#       <td>0.25</td>
#       <td>93.27</td>
#       <td>0.54</td>
#       <td>97.20</td>
#       <td>0.16</td>
#       <td>11.37</td>
#       <td>0.56</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">CIFAR100</th>
#       <th>G-CAC</th>
#       <td>2.15</td>
#       <td>0.07</td>
#       <td>45.27</td>
#       <td>1.96</td>
#       <td>49.13</td>
#       <td>1.41</td>
#       <td>56.31</td>
#       <td>1.43</td>
#       <td>82.23</td>
#       <td>2.03</td>
#     </tr>
#     <tr>
#       <th>G-Center</th>
#       <td>71.05</td>
#       <td>0.04</td>
#       <td>52.50</td>
#       <td>2.58</td>
#       <td>54.42</td>
#       <td>1.57</td>
#       <td>63.35</td>
#       <td>1.91</td>
#       <td>73.36</td>
#       <td>2.26</td>
#     </tr>
#     <tr>
#       <th>G-MCHAD</th>
#       <td>75.50</td>
#       <td>0.03</td>
#       <td>75.99</td>
#       <td>1.46</td>
#       <td>71.29</td>
#       <td>1.41</td>
#       <td>80.98</td>
#       <td>1.12</td>
#       <td>52.99</td>
#       <td>2.29</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">SVHN</th>
#       <th>G-CAC</th>
#       <td>94.24</td>
#       <td>0.03</td>
#       <td>98.81</td>
#       <td>0.18</td>
#       <td>97.92</td>
#       <td>0.30</td>
#       <td>99.17</td>
#       <td>0.13</td>
#       <td>5.61</td>
#       <td>0.98</td>
#     </tr>
#     <tr>
#       <th>G-Center</th>
#       <td>95.86</td>
#       <td>0.01</td>
#       <td>99.31</td>
#       <td>0.11</td>
#       <td>98.23</td>
#       <td>0.28</td>
#       <td>99.69</td>
#       <td>0.05</td>
#       <td>2.64</td>
#       <td>0.40</td>
#     </tr>
#     <tr>
#       <th>G-MCHAD</th>
#       <td>95.72</td>
#       <td>0.01</td>
#       <td>99.34</td>
#       <td>0.06</td>
#       <td>96.98</td>
#       <td>0.27</td>
#       <td>99.78</td>
#       <td>0.02</td>
#       <td>2.23</td>
#       <td>0.19</td>
#     </tr>
#   </tbody>
# </table>

# %%
tmp.groupby(by=["Dataset", "Model"]).agg(
    {
        "Accuracy": ["mean", "sem"],
        "AUROC": ["mean", "sem"],
        "AUPR-IN": ["mean", "sem"],
        "AUPR-OUT": ["mean", "sem"],
        "FPR95": ["mean", "sem"],
    }
)
# Out:
#                     Accuracy                AUROC              AUPR-IN  \
#                         mean       sem       mean       sem       mean
# Dataset  Model
# CIFAR10  G-CAC     71.836666  2.694677  73.580785  1.955962  73.199430
#          G-Center  94.296667  0.014898  92.216523  0.570037  87.718848
#          G-MCHAD   94.735714  0.012563  96.111539  0.252294  93.274192
# CIFAR100 G-CAC      2.147143  0.065956  45.274222  1.958682  49.133218
#          G-Center  71.054761  0.040074  52.500279  2.582255  54.415062
#          G-MCHAD   75.501905  0.027099  75.991821  1.455793  71.289083
# SVHN     G-CAC     94.238227  0.033890  98.813229  0.176501  97.919831
#          G-Center  95.864796  0.009919  99.313390  0.106959  98.225935
#          G-MCHAD   95.720652  0.007386  99.342423  0.056037  96.984019
#
#                               AUPR-OUT                FPR95
#                         sem       mean       sem       mean       sem
# Dataset  Model
# CIFAR10  G-CAC     1.770432  74.305933  1.570403  65.690544  2.771061
#          G-Center  0.912229  93.990460  0.436738  21.521565  1.284223
#          G-MCHAD   0.535166  97.200219  0.164815  11.369048  0.558939
# CIFAR100 G-CAC     1.411857  56.310972  1.432123  82.227823  2.032351
#          G-Center  1.571214  63.354717  1.906762  73.357687  2.264232
#          G-MCHAD   1.409909  80.984310  1.118581  52.989728  2.290656
# SVHN     G-CAC     0.303281  99.171820  0.129342   5.613447  0.983186
#          G-Center  0.282568  99.690595  0.049597   2.644809  0.396864
#          G-MCHAD   0.268915  99.784019  0.019316   2.228027  0.191017

# %%
from scipy.stats import ttest_ind

tmp = df.reset_index().copy()
# tmp = tmp[(tmp["Model"] == "MCHAD") | (tmp["Model"] == "G-MCHAD")]

for metric in ["Accuracy", "AUROC", "AUPR-IN", "AUPR-OUT", "FPR95"]:
    for dataset in ["SVHN", "CIFAR10", "CIFAR100"]:
        a = tmp[(tmp["Model"] == "CAC") & (tmp["Dataset"] == dataset)][metric]
        b = tmp[(tmp["Model"] == "MCHAD") & (tmp["Dataset"]== dataset)][metric]
        stat, p = ttest_ind(a,b, equal_var=False)
        print(f"{metric} {dataset} -> {p < 0.05} ")
# Out:
# Accuracy SVHN -> False
# Accuracy CIFAR10 -> False
# Accuracy CIFAR100 -> False
# AUROC SVHN -> False
# AUROC CIFAR10 -> False
# AUROC CIFAR100 -> False
# AUPR-IN SVHN -> False
# AUPR-IN CIFAR10 -> False
# AUPR-IN CIFAR100 -> False
# AUPR-OUT SVHN -> False
# AUPR-OUT CIFAR10 -> False
# AUPR-OUT CIFAR100 -> False
# FPR95 SVHN -> False
# FPR95 CIFAR10 -> False
# FPR95 CIFAR100 -> False
